# %%
# The question of number two (2)
# Function of the dequeues
def createDeque():
  d=[]
  return (d)
def addFront(d,data):
  d.insert(0,data)
  return(d)
def addRear(d,data):
  d.append(data)
  return(d)
def removeRear(d):
  data=d.pop()
  return(data)
def removeFront(d):
  data=d.pop(0)
  return(data)
def isEmpty(d):
  return (d==[])
def size(d):
  return (len(d))

data_pasien = [
  {"nama": "Sari", "kondisi": "stabil"},
  {"nama": "Andi", "kondisi": "kritis"},
  {"nama": "Lina", "kondisi": "stabil"},
  {"nama": "Bimo", "kondisi": "kritis"},
  {"nama": "Fahmi", "kondisi": "kritis"},
  {"nama": "Rudi", "kondisi": "kritis"},
]

antrian_stabil = createDeque()
antrian_kritis = createDeque()
antrian_final = createDeque()
step1 = 1
tunggu = 1
print("Pasien baru datang: ")
for pasien in data_pasien:
  print(f"{step1} - {pasien['nama']} ({pasien['kondisi']})")
  step1 += 1
  if pasien["kondisi"] == "kritis":
      addRear(antrian_kritis, pasien)
      tunggu +=  1
  else:
      addRear(antrian_stabil, pasien)
  if tunggu == 4:
    hapus = removeFront(antrian_stabil)
    addRear(antrian_kritis, hapus)
    tunggu = 1
  while not isEmpty(antrian_kritis):
    hapus2 = removeFront(antrian_kritis)
    addRear(antrian_final, hapus2)
while not isEmpty(antrian_stabil):
  hapus3=removeFront(antrian_stabil)
  addRear(antrian_final, hapus3)
print("\nAntrian seteleah di flter sekarang :")
step2 = 1
for pasien in antrian_final:
  print(f"{step2} - {pasien['nama']} ({pasien['kondisi']})")
  step2 += 1
# Out:
# Pasien baru datang:
# 1 - Sari (stabil)
# 2 - Andi (kritis)
# 3 - Lina (stabil)
# 4 - Bimo (kritis)
# 5 - Fahmi (kritis)
# 6 - Rudi (kritis)
#
# Antrian seteleah di flter sekarang :
# 1 - Andi (kritis)
# 2 - Bimo (kritis)
# 3 - Fahmi (kritis)
# 4 - Sari (stabil)
# 5 - Rudi (kritis)
# 6 - Lina (stabil)

# %%
# The question of number two (2)
# Function of the dequeues
def createDeque():
  d=[]
  return (d)
def addFront(d,data):
  d.insert(0,data)
  return(d)
def addRear(d,data):
  d.append(data)
  return(d)
def removeRear(d):
  data=d.pop()
  return(data)
def removeFront(d):
  data=d.pop(0)
  return(data)
def isEmpty(d):
  return (d==[])
def size(d):
  return (len(d))

data_pasien = [
  {"nama": "Sari", "kondisi": "stabil"},
  {"nama": "Andi", "kondisi": "kritis"},
  {"nama": "Lina", "kondisi": "stabil"},
  {"nama": "Bimo", "kondisi": "kritis"},
  {"nama": "Fahmi", "kondisi": "kritis"},
  {"nama": "Rudi", "kondisi": "kritis"},
]

antrian = createDeque()
step1 = 1
print("Antrian awal : ")
for pasien in data_pasien:
  print(f"{step1} - {pasien['nama']} ({pasien['kondisi']})")
  if pasien["kondisi"] == "kritis":
      addFront(antrian, pasien)
  else:
      addRear(antrian, pasien)
  step1 += 1
print("\nAntrian seteleah di flter sekarang : ")
step2 = 1
for pasien in antrian:
  print(f"{step2} - {pasien['nama']} ({pasien['kondisi']})")
  step2 += 1
# Out:
# Antran awal :
# 1 - Sari (stabil)
# 2 - Andi (kritis)
# 3 - Lina (stabil)
# 4 - Bimo (kritis)
# 5 - Fahmi (kritis)
# 6 - Rudi (kritis)
#
# Antrian seteleah di flter sekarang :
# 1 - Rudi (kritis)
# 2 - Fahmi (kritis)
# 3 - Bimo (kritis)
# 4 - Andi (kritis)
# 5 - Sari (stabil)
# 6 - Lina (stabil)

# %%
def createDeque():
    d = []
    return d

def addFront(d, data):
    d.insert(0, data)
    return d

def addRear(d, data):
    d.append(data)
    return d

def removeRear(d):
    data = d.pop()
    return data

def removeFront(d):
    data = d.pop(0)
    return data

def isEmpty(d):
    return d == []

def size(d):
    return len(d)

data_pasien = [
    ("Sari", "Stabil"),
    ("Andi", "Kritis"),
    ("Lina", "Stabil"),
    ("Bimo", "Kritis"),
    ("fahmi", "Kritis"),
    ("Rudi", "Kritis"),
]
antrian = createDeque()
pasien_baru = 0
for nama,status in data_pasien:
  if status == 'Kritis':
    addFront(antrian,nama)
    pasien_baru +=1
  if status == 'Stabil':
    addRear(antrian,nama)
    pasien_baru +=1
    if pasien_baru > 3:
      prioritas = removeRear('Stabil')
      addFront(antrian,'Stabil')
      pasien_baru = 0

print('Urutan antrian pasien yang dilayani:')
while not isEmpty(antrian):
  pasien = removeFront(antrian)
  print(pasien)
# Out:
# Urutan antrian pasien yang dilayani:
# Rudi
# fahmi
# Bimo
# Andi
# Sari
# Lina
